# %% [markdown]
# <a href="https://colab.research.google.com/github/anasbenbrahim/Python-AI-Foundations/blob/master/Python_AI_Foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Converting integer to float**

# %%
integer_number = 12345
float_number = 1.2345
float_number2 = 3.3

new_number = integer_number + float_number
new_number2 = new_number + float_number2

print("Value:",new_number)
print("Data Type:",type(new_number))
print("New Value:",new_number2)
# Out:
# Value: 12346.2345
# Data Type: <class 'float'>
# New Value: 12349.5345

# %% [markdown]
# # **Explicit Type Conversion**

# %%
num_string = '12'
num_integer = 23

print("Data type before Type Casting:",type(num_string))

# explicit type conversion
num_string = int(num_string)

print("Data type before Type Casting:",type(num_string))

num_sum = num_integer + num_string

print("Sum:",num_sum)
print("Data type of sum:",type(num_sum))
# Out:
# Data type before Type Casting: <class 'str'>
# Data type before Type Casting: <class 'int'>
# Sum: 35
# Data type of sum: <class 'int'>

# %% [markdown]
# # **Python Basic Input and Output**

# %%
print('Python')
# Out:
# Python

# %%
print('New Year', 2026, 'See you', sep= '. ')
# Out:
# New Year. 2026. See you

# %%
print('Anas ' + 'Ben ibrahim')
# Out:
# Anas Ben ibrahim

# %% [markdown]
# ## ***Output formatting***

# %%
x = 5
y = 10

print('The value of x is {} and y is {}'.format(x,y))
# Out:
# The value of x is 5 and y is 10

# %% [markdown]
# ## ***Python Input***

# %%
# Using input() to take user input
num = input('Enter a number: ')

print('You Entred:', num)

print('Data type of num:', type(num))
# Out:
# Enter a number: 22
# You Entred: 22
# Data type of num: <class 'str'>

# %%
# To convert user input into a number we can use int() or float() functions as :
num = int(input('Enter a number: '))

print('Data type of num:', type(num))
# Out:
# Enter a number: 55
# Data type of num: <class 'int'>

# %% [markdown]
# # **Python Operators**

# %% [markdown]
# ## ***Example 1: Arithmetic Operators in Python***
